# %% [markdown]
# <a href="https://colab.research.google.com/github/NdcProfessor/vuejs/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(f"O tempo estimado de viagem é de: {408 / 100:.2f} horas")
# Out:
# O tempo estimado de viagem é de: 4.08 horas
